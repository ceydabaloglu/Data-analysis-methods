# %% [markdown]
# <a href="https://colab.research.google.com/github/ceydabaloglu/Data-analysis-methods/blob/master/%C3%9Cbung4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #%20 oranında train-test random bölündü

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.model_selection import train_test_split

path ="SunspotGroupData.txt"
data = pd.read_csv(path,sep="\s+")
#data = pd.read_fwf("SunspotGroupData.txt")
data
print(data)
train,test = train_test_split(data,test_size=0.2)
#%20 oranında train-test random bölündü
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2   ua   ws    lat     lon  \
# 0      g  1976   1  12  12  11  35    675    4    9    3    5  -8.40   33.95
# 1      g  1976   1  12  12  11  35    676   10   80   15  127 -11.45  284.27
# 2      g  1976   1  14   1  13  30    675    0    5    0    4 -10.84   35.05
# 3      g  1976   1  14   1  13  30    676  128  700  106  581 -10.25  283.47
# 4      g  1976   1  15  10  22   2    675    0    1    0    3 -10.25   36.58
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ...  ...    ...     ...
# 57673  g  1996  12  22   8  10   0  8007a    0    6    0    3  -7.28  176.21
# 57674  g  1996  12  23   2  35   0   8004    9   49   16   90   5.77  251.93
# 57675  g  1996  12  23   2  35   0   8007    2   11    2   13   5.18  240.00
# 57676  g  1996  12  24  11  16  49   8008    1    5    1    3 -18.96  168.17
# 57677  g  1996  12  26   8  31  32  8008a    0    2    0    1 -22.36  148.04
#
#          lcm      pa    dcen
# ...

# %%
test
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2   ua   ws    lat     lon  \
# 42217  g  1990   5  14  11  20  52   6064   96  647  106  674 -15.43  311.00
# 56749  g  1995   2  20  12   7  51   7838    7   49   11   85   8.34  115.86
# 6055   g  1979   2  11   6   1  30   1563    1   14    1    9 -22.60  220.29
# 52479  g  1992   8  13   7  40  16  7262m    0    2    0    2   7.63  328.73
# 25567  g  1982  10  29  10  48  43   3955    0   25    0   24 -10.24   53.80
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ...  ...    ...     ...
# 18270  g  1981   4  22   8  48  30  3068m    0    4    0    2  -4.16  116.96
# 55889  g  1994   5  14   5  52  12   7725    0    2    0    1   5.42  145.21
# 26640  g  1983   2  10   7  14  32  4087m    0    6    0    2  -2.36   77.54
# 39312  g  1989  10   4   8  11  31   5715   15   57   11   40 -25.33   92.45
# 52164  g  1992   6  30   7   7   3   7217    8   28    5   15   7.54  158.72
#
#          lcm      pa    dcen
# ...

# %%
train
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2  ua   ws        lat  \
# 48547  g  1991   8  11   6  49  40   6766    7   13   5    7       9.36
# 20343  g  1981   9  10   6  32  22   3335    0    0   0    0  999999.00
# 30773  g  1984   9   1  15  23  56   4573    0    2   0    2      -0.12
# 38930  g  1989   9   3   7   9  28  5668a    0    3   0    3     -40.95
# 13935  g  1980   6  26  11   4  43  2530m    0    8   0    4     -20.32
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ..  ...        ...
# 14901  g  1980   8  22  13   1  10  2635m    0    2   0    1      23.64
# 21115  g  1981  10  28  12  32  55   3429    0   11   0   16     -21.47
# 28342  g  1983   8   2   7  46  58   4268    3   19   2   13      -3.88
# 20952  g  1981  10  16   8  52  50   3406  103  958  99  938      -7.94
# 13158  g  1980   5  13  13   9  41  2453o    0    4   0    3      19.69
#
#              lon        lcm         pa         dcen
# ...

# %% [markdown]
# #bins ile lat verilerinin 10 lu parçalara ayırma

# %%
x = pd.qcut(data.lat, q=10)
x.value_counts()
# Out:
# (-1.64, 9.17]        5777
# (-55.861, -22.97]    5771
# (-17.64, -13.35]     5768
# (-9.55, -1.64]       5768
# (-22.97, -17.64]     5767
# (13.92, 18.32]       5767
# (-13.35, -9.55]      5766
# (24.83, 999999.0]    5766
# (9.17, 13.92]        5764
# (18.32, 24.83]       5764
# Name: lat, dtype: int64

# %% [markdown]
# # **40 ile -40 arasındaki değerlerin sıralanması **

# %%
data[data["lat"] > 40] = np.sign(40) 
data[data["lat"] < -40] = np.sign(-40)
data.describe()
# Out:
#                  yr            mo            da            hr            mi  \
# count  57678.000000  57678.000000  57678.000000  57678.000000  57678.000000
# mean    1905.501058      6.279032     15.071518      8.863189     28.462481
# std      389.159153      3.486440      9.067105      3.698911     17.794706
# min       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 25%     1980.000000      3.000000      7.000000      6.000000     13.000000
# 50%     1983.000000      6.000000     15.000000      9.000000     28.000000
# 75%     1990.000000      9.000000     23.000000     12.000000     44.000000
# max     1996.000000     12.000000     31.000000     23.000000     59.000000
#
#                  se           pr1           pr2            ua            ws  \
# count  57678.000000  57678.000000  57678.000000  57678.000000  57678.000000
# mean      26.931551     29.818752    199.046118     21.339974    146.382451
# ...
