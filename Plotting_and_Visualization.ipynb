# %% [markdown]
# <a href="https://colab.research.google.com/github/ceydabaloglu/Data-analysis-methods/blob/master/Plotting_and_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = joblib.load('dfo.joblib')
df
# Out:
#             mjd         year  idn   lat    lon   rho   area  carea   carl  nss
# 0      35091.28  1954.954191   21  34.0   82.0  0.58  146.0  104.0   56.0    8
# 1      35094.25  1954.962328   22  24.5  337.5  0.94    8.0   11.0   11.0    1
# 2      35100.26  1954.978794   23  35.0  336.5  0.61   30.0   19.0   19.0    1
# 3      35105.20  1954.992328   24 -24.0  251.5  0.39   36.0   20.0   20.0    1
# 4      35111.33  1955.009123    1  20.5  128.0  0.86   58.0   57.0   28.0    5
# ...         ...          ...  ...   ...    ...   ...    ...    ...    ...  ...
# 19562  55557.28  2010.987068  124  12.0  320.0  0.26   82.0   43.0   16.0    9
# 19563  55559.39  2010.992849  125 -25.7  233.5  0.86   20.0   20.0   15.0    2
# 19564  55561.31  2010.998109  125 -27.3  234.4  0.63    8.0    5.0    3.0    2
# 19565  55561.31  2010.998109  126  34.7  266.9  0.61  102.0   64.0   38.0    5
# 19566  55561.31  2010.998109  127  31.4  190.8  0.97  116.0  246.0  246.0    1
#
# ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(10,8))

plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.4)

axes[0,0].scatter (df.lon,df.lat,alpha=0.2 , s=2 ,color ="green" )
axes[0,1].scatter (df.year,df.lon,alpha=0.2 , s=2,color ="blue")
axes[0,2].scatter (df.year,df.lat,alpha=0.2 , s=2,color ="pink")
axes[1,2].scatter (df.year,df.carea,alpha=0.2 , s=2, color ="yellow")
axes[1,1].hist (df.carea,20,log=True ,alpha=0.2, color= "black")
axes[1,0].hist (df.lat,20,alpha=0.2 )
# Out:
# (array([9.000e+00, 5.300e+01, 1.760e+02, 5.950e+02, 1.177e+03, 2.165e+03,
#         2.941e+03, 1.823e+03, 5.990e+02, 1.177e+03, 2.534e+03, 2.751e+03,
#         1.853e+03, 1.140e+03, 3.740e+02, 1.550e+02, 3.700e+01, 6.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([-51. , -45.2, -39.4, -33.6, -27.8, -22. , -16.2, -10.4,  -4.6,
#           1.2,   7. ,  12.8,  18.6,  24.4,  30.2,  36. ,  41.8,  47.6,
#          53.4,  59.2,  65. ]),
#  <a list of 20 Patch objects>)

# %%
axes[0,0].set_xlabel("Longitude") 
axes[0,0].set_ylabel("Latitude")

axes[0,1].set_xlabel("Year") 
axes[0,1].set_ylabel("Longitude")

axes[0,2].set_xlabel("Year") 
axes[0,2].set_ylabel("Latitude")

axes[1,2].set_xlabel("Year") 
axes[1,2].set_ylabel("Carea")

axes[1,2].set_xlabel("Year") 
axes[1,2].set_ylabel("Carea")

axes[1,1].set_xlabel("Carea") 
axes[1,1].set_ylabel("Frequency")

axes[1,0].set_xlabel("Latitude") 
axes[1,0].set_ylabel("Frequency")

fig

# %%
df['lat'].plot.density()

# %%
fig = plt.figure(figsize=(8,10))
p = sns.scatterplot(data = df[df.year < 1962], x ="lon", y="year", size = "carea", alpha = .3 ,hue="lat",sizes=(20,400),
                    palette='dark:orchid')

sns.kdeplot(data=df[df.year < 1962], x="lon" ,y = "year", bw_adjust=.3 ,alpha=.5, thresh=.5, color="blue")
